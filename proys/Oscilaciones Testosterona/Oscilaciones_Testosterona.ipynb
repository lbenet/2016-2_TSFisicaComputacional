# %% [markdown]
# ## Proyecto TSFC: Oscilaciones en Sistemas Biológicos
#
# ## Comportamiento de Testosterona
#
# ### Hernández de la Vega Alejandro
# ### Rodríguez Rosenblueth César Daniel
# ### Santiago Santos Eva Yazmín

# %% [markdown]
# # Osciladores biológicos #
#
#
# Bien sea la respiración, la elaboración de marcapasos para asistir la actividad cardiaca o la secreción de testosterona en los hombres, existen varios sistemas biológicos que exhiben un carácter oscilatorio. Una primera aproximación para el estudio de estos sistemas desemboca en ecuaciones diferenciales ordinarias del tipo:
#
# $$\dfrac{du}{dt} = f(u),$$
#
# Donde, para soluciones periódicos se tiene:
#
# $$u(t+T)= u(t),$$
#
# con el periodo $T>0$ En el espacio fase de concentraciones la trayectoria de esta solución describe una órbita cerrada.
#
# En la descripción de sistemas biológicos, estos modelos de ecuaciones diferenciales vienen acompañados de parámetros $\lambda$ por lo que el comportamiento de las soluciones *u*(t,$\lambda$) varían con los valores o rangos de dichos parámetros. Generalmente, las soluciones de estado estacionario, es decir soluciones tal que $f(u)=0$, son estables a pequeñas perturbaciones si $\lambda$ pertenece a cierto intervalo, y se vuelven inestables si $\lambda_c$ excede un valor crítico, denominado _punto de bifurcación_.
#
# Empleando uno de los resultados del _teorema de bifurcación de Hopf_ tenemos que:
#
# Si se supone que *u*$=0$ es una solución de estado estacionario y al linealizarla arroja un par de eigenvalores complejos conjugados $\alpha(\lambda) = $ Re$\alpha \pm iIm\alpha$. Donde estos eigenvalores tienen la parte real de mayor magnitud entre todos los eigenvalores y son tales que en una pequeña vecindad alrededor de un punto de bifurcación $\lambda_c$ se cumple:
#
# + Re $\alpha<0$ si $\lambda < \lambda_c ,$
# + Re $\alpha=0$ y Im$\alpha \neq 0$ si $\lambda = \lambda_c ,$
# + Re $\alpha >0$ si $\lambda > \lambda_c ,$
#
# Entonces en una  pequeña vecindad de $\lambda_c$ , $\lambda > \lambda_c$ el estado estacionario es inestable por oscilaciones crecientes y _existe una solución de ciclo límite  _ alrededor de *u*$=0$.
#
# Ahora bien, existen casos (como en la síntesis de enzimas durante la división celular o en el estudiado en este trabajo) donde el sistema viene regulado por un control de retroalimentación. En este sentido, el sistema viene dado por una serie de reacciones ligadas, llevándose a cabo una reacción seguida de otra y en donde la primera de éstas viene regulada por una función de retroalimentación que involucra la última reacción, i.e. si tenemos n reacciones:
#
# $$ \dfrac{d u_1}{dt} = f(u_n )k_1 u_1 ,$$
# $$ \dfrac{d u_r}{dt} = u_{r-1} -k_r u_r ,$$
#
# con $r=2,3,...,n$. Además, $ k_r > 0 $ son constantes determinadas por el sistema en cuestión y $ f(u)$ es la función de retroalimentación.
#
# Los trabajos de Tyson y de Othmer(1978), y Yagil (1971) muestran que la función de retroalimentación tiene que ser una función siempre positiva y monótona decreciente _para asegurar la unicidad de las soluciones de estado estacionario_.

# %% [markdown]
# # Características de la testosterona #
#
# La testosterona es una hormona cuya función principal es estimular el desarrollo de los caracteres sexuales masculinos, y está presente en mamíferos, reptiles y aves. Para el ser humano, en los hombres el nivel de testosterona se encuentra entre 10-35 nanomoles por litro de sangre, mientras que en las mujeres es de 0.7-2.7 nanomoles por litro. La testosterona es principalmente producida en los testículos en los hombres y en los ovarios en las mujeres. En los hombres, los niveles de testoterona oscilan con un periodo de 2 a 3 horas.
#
# Existen cambios de personalidad relacionados con la concentración de testosterona en la sangre. Por ejemplo, niveles bajos de testosterona vienen acompañados con actitudes dóciles en los sujetos. Además, pacientes que padecen de cáncer de próstata, son sometidos a un tratamiento que involucra la suministración de _Goserelina_, una droga que al término de un par de semanas reduce el nivel de testosterona al grado que se alcanzaría a través de la castración.

# %% [markdown]
# ## Secreción de la testosterona##
#
# La secreción de testosterona (T) por parte de las gónadas viene regulada por la hormona luteinizante (LH), generada en la glándula pituitaria. Esta última viene regulada, a su vez, por la hormona liberadora de hormona luteinizante (LHRH), que es secretada en el hipotálamo. Además la testosterona ejerce una retroalimentación en la producción de LHRH.
#
# Entonces, en este sistema, el hipotálamo secreta la hormona liberadora de hormona luteinizante que es llevada a través del torrente sanguíneo a la glándula pituitaria, donde se controla la secreción de hormona luteinizante que finalmente controla la producción de testosterona en las gónadas. Es entonces que se ejerce la retroalimentación entre de los testículos hacia el hipotálamo.
#
# Entonces, denotando a T, LH y LHRH por $T(t) L(t)$ y $R(t)$ respectivamente, tenemos que:
#
# $$ \frac{dR}{dt} = f(T)-b_{1}R,$$
# $$ \frac{dL}{dt} = g_{1}R-b_{2}L ,$$
# $$ \frac{dT}{dt} = g_{2}L-b_{3}T .$$

# %% [markdown]
# Matemáticamente, $b_{1}$, $b_{2}$, $b_{3}$, $g_{1}$, $g_{2}$ son parámetros positivos. Biológicamente, $g_{1}$,$g_{2}$ y $f(T)$ son las tasas de secreción de las hormonas LHRH, LH y T respectivamente. Además  $g_{1}$ y $g_{2}$ son los valores de prealimentación para R y L respectivamente y deben estar representadas por funciones monótonas crecientes, mientras que f(T) es la función de retroalimentación para las dos hormonas precursoras. Por otro lado, $b_{1}$, $b_{2}$, $b_{3}$ representan la tasa de difusión de las hormonas en el torrente sanguíneo. Ambos están dados en valores de concentración por hora.
#
# Para los puntos de estabilidad se tiene lo siguiente:
#
# $$L_0 = \dfrac{b_3 T_0}{g2} ,$$
# $$R_0 = \dfrac{b_3 b2 T_0}{g2g2} ,$$
# $$f(T_0)- \dfrac{b_3 b_2 b_1 T_0}{g2g1}=0 .$$
#
# Las ecuaciones anteriores tienen sólución en:
#
# $$R_{0} = \frac{f(T_{0})}{b_{1}},$$
#
# $$L_{0} = \frac{b_{3}}{g_{2}}T_{0},$$
#
# Donde $T_{0}>0,$ satisface $g_{1}g_{2}f(T_{0}) = b_{1}b_{2}b_{3}T_{0}.$
#
# Cuando $f'(T_{0}) < 0,$ no hay estabilidad:
#
# (i) si y sólo si
#
# $$-\frac{g_{1}g_{2}f'(T_{0})}{b_{1}} > \frac{a_{1}a_{2}}{a_{3}}-1,$$
#
# Donde:
#
# $$a_{1} = b_{1}+b_{2}+b_{3},$$
# $$a_{2}=b_{1}b_{2}+b_{1}b_{3}+b_{2}b_{3},$$
# $$a_{3}=b_{1}b_{2}b_{3},$$
#
# (ii) si
#
# $$-\frac{T_{0}f'(T_{0})}{f(T_{0})} > 8 ,$$

# %% [markdown]
# En este notebook se trabaja con funciones de retroalimentación que cumplen estas propiedades para poder obtener sistemas fisiológicamente aceptables en lo que las hormonas R,L y T oscilan en un periodo de tres horas.

# %%
using PyPlot #para graficar
using TaylorSeries #para poder integrar con polinomios de Taylor
using LaTeXStrings #para facilitar el escribir en latex

# %%
function h_find(x::Array,p::Int)
    h1 = (1/10)*(eps(1.0)/abs(x[p+1]))^(1/p)
    h2 = (1/10)*(eps(1.0)/abs(x[p]))^(1/(p-1))
    if h1 - h2 >= 0
        return h2
    else
        return h1
    end
end
# Out:
# h_find (generic function with 1 method)

# %% [markdown]
# ### Primer modelo
#
# En el primer modelo se trabaja con una función de retroaalimentación de la forma $$ f(T) = \frac{A}{K+T^{m}} $$, propuesta en [1]. Sustituyendo esta función en las condiciones de inestabilidad deescritas arriba se encuentra que es necesario que $ m>8 $

# %%
"""
La función Testosterone1 resuelve utilizando coeficientes de Taylor la ecuación diferencial \n
R'(t) = f(T)-b1*R(t), \n
L'(t) = g1*R(t)-b2*L(t), \n
T'(t) = g2*L(t)-b3*T(t), \n

Donde la función de retroalimentación está dada por
f(T) = A/(K+T^m).

La función recibe los valores en el siguiente orden: \n Testosterone1(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,A,K,m) \n
'p' determina el orden del polinomio de Taylor a utilizar. Las letras como R0 representan el valor inicial de R al tiempo 0.
Por otro lado, t0 y tf determinan el tiempo inicial y final en el que se requiere la solución, y
las tasas de difusión de las hormonas están dadas por b1, b2 y b3, y las tasas de secreción y prealimentación, por g1 y g2.

La función regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            fT=A/(K+TT^m)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
    end
    return (t,R,L,T)
end
# Out:
# Testosterone1 (generic function with 1 method)

# %%
?Testosterone1
# Out:
# search: Testosterone1
# La función Testosterone1 resuelve utilizando coeficientes de Taylor la ecuación diferencial
#
# R'(t) = f(T)-b1*R(t),
#
# L'(t) = g1*R(t)-b2*L(t),
#
# T'(t) = g2*L(t)-b3*T(t),
#
# Donde la función de retroalimentación está dada por f(T) = A/(K+T^m).
#
# La función recibe los valores en el siguiente orden:   Testosterone1(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,A,K,m)
#
# 'p' determina el orden del polinomio de Taylor a utilizar. Las letras como R0 representan el valor inicial de R al tiempo 0. Por otro lado, t0 y tf determinan el tiempo inicial y final en el que se requiere la solución, y las tasas de difusión de las hormonas están dadas por b1, b2 y b3, y las tasas de secreción y prealimentación, por g1 y g2.
#
# La función regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.

# %% [markdown]
# De la teoría se sabe que los valores estacionarios no dependen de los valores iniciales, por lo que el sistema no es caótico. No importa que tanto se alteran los valores iniciales el sistema eventualmente llega a la misma solución estacionaria o periódica.

# %%
#Valores iniciales
R0=1.0
L0=2.0
T0=1.5

# Tasa de difusión
b1=1.29
b2=0.97
b3=1.39

#Tasas de secreción y prealimentación
g1=10
g2=0.7
    
#Valores para la función f(T)
A=2
K=1
m=12

#Intervalo
t0=0.0
tf=100

#Orden de coeficientes
p=10

t_12=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[1];
R_12=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[2];
L_12=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[3];
T_12=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[4];

# %%
#Probemos distintos valores de m
m=4
t_4=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[1];
R_4=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[2];
L_4=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[3];
T_4=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[4];

m=8
t_8=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[1];
R_8=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[2];
L_8=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[3];
T_8=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[4];

m=9.5
t_9_5=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[1];
R_9_5=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[2];
L_9_5=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[3];
T_9_5=Testosterone1(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m)[4];

# %%
plot(t_12,T_12,"b-",label="m=12")
plot(t_9_5,T_9_5,"g-",label="m=9.5")
plot(t_8,T_8,"r-",label="m=8")
plot(t_4,T_4,"k-",label="m=4")


title("Concentración de Testorona en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")
#ylim(0.8,2.2)

legend(loc="upper right",fancybox="true")
#savefig("concentracion_testosterona_primer_modelo.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002457CBA8>)
# PyObject <matplotlib.legend.Legend object at 0x0000000026ED3F28>

# %% [markdown]
# Como se puede apreciar en la gráfica anterior, el valor del parámetro m, con A y K constantes, determina el carácter de estabilidad de la concentración de testosterona en la sangre. Esto va de acuerdo a lo mencionado préviamente, teniendo a $m=8$ como el punto de bifurcación sugerido por Smith(1980), a partir del cual las soluciones del modelo se vuelven inestables y desembocan en un comportamiento oscilatorio, en contraposición a valores $ m < 8$, donde el comportamiento se estabiliza a un valor estacionario.
#
# No obstante, se puede apreciar que en las gráficas las oscilaciones para este valor de m se extinguen a partir de cierto tiempo y que para un valor de m mayor o igual que 9.5 estas oscilaciones reducen su amplitud pero se mantienen oscilando. De esta manera se puede observar una dependencia entre la amplitud de la oscilación y la magnitud de m, y que esta amplitud alcanza un valor constante de manera más rápida conforme la magnitud de m aumenta.
#
# Esto se construyó para unos valores de A y de K fijos aribtrarios, por lo que se podría inferir la existencia de una relación entre los parámetros del modelo y el valor del punto de bifurcación.

# %%
plot(t_12,R_12,"b-",label="m=12")
plot(t_9_5,R_9_5,"g-",label="m=9.5")
plot(t_8,R_8,"r-",label="m=8")
plot(t_4,R_4,"k-",label="m=4")


title("Concentración de LHRL en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000026EF27F0>)
# PyObject <matplotlib.legend.Legend object at 0x0000000020980908>

# %% [markdown]
# Se observa el mismo comportamiento para esta hormona que para la testosterona.

# %%
plot(t_12,L_12,"b-",label="m=12")
plot(t_9_5,L_9_5,"g-",label="m=9.5")
plot(t_8,L_8,"r-",label="m=8")
plot(t_4,L_4,"k-",label="m=4")


title("Concentración de LH en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000208944A8>)
# PyObject <matplotlib.legend.Legend object at 0x0000000020909630>

# %% [markdown]
# Se puede observar que para LH, la concentración tiene un comportamiento muy similar a las otras dos hormonas. Su principal diferencia es la amplitud entre las tres.

# %%
plot(t_12,R_12,"r-",label="R")
plot(t_12,T_12,"b-",label="T")
plot(t_12,L_12,"g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("g2.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000208FE860>)
# PyObject <matplotlib.legend.Legend object at 0x0000000026F2F1D0>

# %% [markdown]
# En la gráfica anterior se muestra la concentración de las tres hormonas para una m fija. Se obtiene que, en general, la concentración de L es mayor que las otras dos, al igual que la amplitud. Además se puede observar que la periodicidad de cada hormona es la misma. Esto era de esperarse pues ya se vio que las tres hormonas se regulan entre ellas.

# %% [markdown]
# A continuación se muestra la relación entre L y T a medida que transcurre el tiempo.

# %%
plot3D(t_9_5,L_9_5,T_9_5)

title("Concentración de suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")

#savefig("g2.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000020942F60>)
# PyObject <matplotlib.text.Text object at 0x000000002C793668>

# %% [markdown]
# Se observa que hay una periodicidad debido al comportamiento circular en el espacio fase, pero la amplitud del ciclo disminuye a medida que el tiempo transcurre.

# %% [markdown]
# Ahora tenemos los diagramas de concentración, para distintos valores de m (siguiendo el esquema de colores definido en las primeras gráficas)

# %%
plot3D(t_12,L_12,T_12,"b-",label="m=12")
plot3D(t_8,L_8,T_8,"r-",label="m=8")
plot3D(t_4,L_4,T_4,"k-",label="m=4")

title("Concentración de suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")

legend(loc="upper right",fancybox="true")
#savefig("g3.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002DDE9320>)
# PyObject <matplotlib.legend.Legend object at 0x000000002E362C50>

# %% [markdown]
# Si graficamos ahora en 2D

# %%
plot(L_12,T_12,"b-",label="m=12")
plot(L_8,T_8,"r-",label="m=8")
plot(L_4,T_4,"k-",label="m=4")

title("Concentración de suero")
xlabel(L"L[\frac{ng}{ml}]")
ylabel(L"T[\frac{ng}{ml}]")

legend(loc="upper right",fancybox="true")
#savefig("g4_2D.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E3BDF98>)
# PyObject <matplotlib.legend.Legend object at 0x000000002DDE9748>

# %% [markdown]
# Podemos ver que los diagramas de concentración se comportan como lo esperado a los diagramas de fase mencionado en la introducción, esto es, para valores mayores al del bifurcación $m > m_c = 9.5$, la solución conforma a una órbita cerrada y exhibe el comportamiento de ciclo límite.

# %%
plot3D(t_8,T_8,g2*L_8-b3*T_8)

title("Concentración de suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E3F17B8>)
# PyObject <matplotlib.text.Text object at 0x000000002DE93E10>

# %%
#Analisis de los valores de estabilidad dados en la introducción

    # Tasa de difusión
    b1=1.29
    b2=0.97
    b3=1.39
    #Tasas de secreción y prealimentación
    g1=10
    g2=0.7

A=2
K=1
m=4
f(T)=A/(K+T^m)
T_4[end]*b1*b2*b3
# Out:
# 2.536106149230389

# %%
f(T_4[end])*g1*g2
# Out:
# 2.5361061492303683

# %%
R_4[end]
# Out:
# 0.28085339415618743

# %%
f(T_4[end])/b1
# Out:
# 0.28085339415618693

# %%
L_4[end]
# Out:
# 2.8953958160431834

# %%
b3/g2*T_4[end]
# Out:
# 2.8953958160431887

# %% [markdown]
# ### Segundo Modelo: Modelo para la esquizofrenia catatónica

# %% [markdown]
# Danzinger y Elmergreen postularon en (1956) un trabajo (analizado posteriormente por Cronin en 1976) en donde se modela matemáticamente la esquizofrenia catatónica periódica. Este modelo es similar a:
#
# $$ \frac{dR}{dt} = f(T)-b_{1}R. $$
# $$ \frac{dL}{dt} = g_{1}R-b_{2}L. $$
# $$ \frac{dT}{dt} = g_{2}L-b_{3}T. $$
#
# pero la función de retroalimentación f(t) que se empleó en este caso es de la forma:
#
# $$ f(z) = (c-hz)[1-H(z-c/h)].  $$
#
# Donde $H(z)$ es la función escalón de Heaviside y $c,h$ son constantes y en donde los criterios de inestabilidad al sustituir f(z) son:
#
# $$ K = \dfrac{g_1 g_2 h}{b_1 b_2 b_3} > \dfrac{a_1 a_2}{a_3} - 1. $$
#
# Usando el mismo criterio para la función de retroalimentación:
#
# $$ K = \dfrac{g_1 g_2 h}{b_1 b_2 b_3} > 8. $$
#
# El análisis de Cronin mostró que cuando el punto de equilibrio es estable no existen soluciones periódicas. Sin embargo, cuando el punto de equilibrio es inestable las soluciones son periódicas, casi periódicas u oscilan de manera no peródica.
#
# Desde el punto de vista fisiológico, el modelo descrito por Danzinger y Elmergreen remplaza R, L, T por la hormona tirotropina, una enzima intermediaria y la hormona tiroidea, respectivamente. La esquizofrenia catatónica periódica se caracteriza por variaciones oscilantes de las concentraciones de estas hormonas, mientras que el estado saludable es caracterizado por una concentración constante de éstas. Estas situaciones corresponden, respectivamente, a puntos de equilibrio inestables y estables de:
#
# $$ \frac{dR}{dt} = (c-hT)[1-H(T-c/h)]-b_{1}R. $$
# $$ \frac{dL}{dt} = g_{1}R-b_{2}L. $$
# $$ \frac{dT}{dt} = g_{2}L-b_{3}T. $$
#
#
# Danzinger y Elmergreen usaron este modelo para proponer un tratamiento para la esquizofrenia catatónica, en el cual si se añade un término constante al 3er término de la última ecuación, que sería el equivalente de tener una secreción constante de la hormona tiroidea, convierte la solución de equilibrio intestable (_patológica_) a una estable, recuperando el estado saludable para el paciente (_normal_).
#
#
# ### Comparación entre el modelo de DE y el de secreción de testosterona###
#
# En el modelo DE para la esquizofrenia catatónica periódica y el modelo de secreción de testosterona, el estado "_normal_" y el "_patológico_" del sistema están intercambiados. Para la secreción de testosterona, concentraciones hormonales oscilantes corresponden al estado normal, mientras que en el modelo DE el estado normal se da con concentraciones hormonales constantes.

# %%
#Heaviside
function H(x)
    if x>0
        return 1
    else
        return 0
    end
end
# Out:
# H (generic function with 1 method)

# %%
function f_step(c,h,t)
    (c-h*t)*(1-H(t-c/h))
end
# Out:
# f_step (generic function with 1 method)

# %%
"""
La función Testosterone2 resuelve utilizando coeficientes de Taylor la ecuación diferencial \n
R'(t) = f(T)-b1*R(t) \n
L'(t) = g1*R(t)-b2*L(t) \n
T'(t) = g2*L(t)-b3*T(t) \n

Donde la función de retroalimentación está dada por
f(T) = (c-hT)(1-H(T-c/h))

La función recibe los valores en el siguiente orden: \n Testosterone2(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f) \n
'p' determina el orden del polinomio de Taylor a utilizar. Las letras como R0 representan el valor inicital de R al tiempo 0.
Por otro lado t0 y tf determinan el tiempo inicial y final en el que se requiere la solución, y
las tasas de difussión de las hormonas están dadas por b1,b2 y b3; las tasas de secreción y prealimentación, por g1 y g2.
h_f y c_f son valores de c y h dentro de f(T)

Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone2(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        fT=Taylor1(f_step(c_f,h_f,T0),p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
    end
    return (t,R,L,T)
end
# Out:
# Testosterone2 (generic function with 1 method)

# %%
?Testosterone2
# Out:
# search: Testosterone2 Testosterone1
# La función Testosterone2 resuelve utilizando coeficientes de Taylor la ecuación diferencial
#
# R'(t) = f(T)-b1*R(t)
#
# L'(t) = g1*R(t)-b2*L(t)
#
# T'(t) = g2*L(t)-b3*T(t)
#
# Donde la función de retroalimentación está dada por f(T) = (c-hT)(1-H(T-c/h))
#
# La función recibe los valores en el siguiente orden:   Testosterone2(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f)
#
# 'p' determina el orden del polinomio de Taylor a utilizar. Las letras como R0 representan el valor inicital de R al tiempo 0. Por otro lado t0 y tf determinan el tiempo inicial y final en el que se requiere la solución, y las tasas de difussión de las hormonas están dadas por b1,b2 y b3; las tasas de secreción y prealimentación, por g1 y g2. h_f y c_f son valores de c y h dentro de f(T)
#
# Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.

# %%
#Valores iniciales
R0=1.0
L0=2.0
T0=1.5

# Tasa de difusión
b1=1.29
b2=0.97
b3=1.39

#Tasas de secreción y prealimentación
g1=10
g2=0.7
    
#Valores para la función f(T)
c=100
h=12

#Intervalo
t0=0.0
tf=80.0

#Orden de coeficientes
p=10

t2_s=Testosterone2(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h)[1];
R2_s=Testosterone2(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h)[2];
L2_s=Testosterone2(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h)[3];
T2_s=Testosterone2(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h)[4];

# %%
plot(t2_s,R2_s,"r-",label="R")
plot(t2_s,T2_s, "b-",label="T")
plot(t2_s,L2_s, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")

#savefig("g5 g2-modelo2")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002DE7CF60>)
# PyObject <matplotlib.legend.Legend object at 0x000000002DE9AB38>

# %% [markdown]
# Empleando los valores mencionados por Smith para el macaco Rhemus, se logró observar una comportamiento oscilante en el sistema, esto va de acuerdo a lo esperado con la teoría, ya que si bien la función de retroalimentación cambió, sigue cumpliendo la característica de ser monótona y decreciente.
#
# Pasando ahora al análisis de los diagramas de concentración:

# %%
#plot3D(t_12,L_12,T_12,"b-")
plot3D(t2_s,L2_s,T2_s,"b-")

title("Concentración de suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")

#savefig("Comparacion_modelo_1_y_2.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E29E9B0>)
# PyObject <matplotlib.text.Text object at 0x000000002F8A0D68>

# %% [markdown]
# Nuevamente logramos apreciar orbitas cerradas y periódicas. El primer circulo con mayor amplitud de debe a las condiciones iniciales introducidas, el sistema se autoregula y llega al comportamiento periódico.

# %% [markdown]
# ### Fuente externa constante de hormonas
#
# Si se agrega un fuente externa constante de hormonas los estados estacionarios se ven alterados. De hecho ocurre que para ciertos valores grandes de inyección de T,R o L el sistema periódico se apaga y encontramos un valor totalmente estacionario. Sean $W_{R},W_{T}$ y $ W_{L}$ son las tasas de inyección de las hormonas R, T y L respectivamente
# por una fuente externa. Entonces se tiene la ecuación:
#
# $$ \frac{dR}{dt} = f(T)-b_{1}R + W_{R} ,$$
# $$ \frac{dL}{dt} = g_{1}R-b_{2}L + W_{L} ,$$
# $$ \frac{dT}{dt} = g_{2}L-b_{3}T + W_{T}.$$
#
# En general el valor crítico en el que se deja de presentar comportamiento periódico está dado por:
#
# $$ g_{1} g_{2} W_{R} + b_{1} g_{2} W_{L} + b_{1} b_{2} W_{T} > c b_{1} b_{2} b_{3} / h $$
#
# Lo que a su vez arroja valores estacionarios:
#
# $$ R_{o} = W_{R}/b_{1} $$
#
# $$ L_{o} = \frac{g_{1} W_{R}/ b_{1} + W_{L}}{b_{2}}$$
#
# $$ T_{o} = \dfrac{g_{1} g_{2} W_{R}/ b_{1} b_{2} + g_{2} W_{L}/b_{2} + W_{T}}{b_{3}}  $$

# %%
"""
La función Testosterone1_Hormones resuelve utilizando coeficientes de Taylor la ecuación diferencial \n
R'(t) = f(T)-b1*R(t)+Wr \n
L'(t) = g1*R(t)-b2*L(t)+Wl \n
T'(t) = g2*L(t)-b3*T(t)+Wt \n

Donde la función de retroalimentación está dada por
f(T) = A/(K+T^m)

Utiliza la misma notación que Tesosterone1 con el extra de que Wr,Wt y Wl son las tasas de inyección de las hormonas
por una fuente externa. Recibe las entradas como Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt).

Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        WrT=Taylor1(Wr,p)
        WlT=Taylor1(Wl,p)
        WtT=Taylor1(Wt,p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            fT=A/(K+TT^m)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i+WrT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i+WlT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i+WtT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
    end
    return (t,R,L,T)
end
# Out:
# Testosterone1_Hormones (generic function with 1 method)

# %%
"""
La función Testosterone2_Hormones resuelve utilizando coeficientes de Taylor la ecuación diferencial \n
R'(t) = f(T)-b1*R(t)+Wr \n
L'(t) = g1*R(t)-b2*L(t)+Wl \n
T'(t) = g2*L(t)-b3*T(t)+Wt \n

Donde la función de retroalimentación está dada por
f(T) = (c-hT)(1-H(T-c/h))

Utiliza la misma notación que Testosteron2, con el extra de que Wr,Wl y Wl son las tasas de inyección de la hormonas por una
fuente externa, y recibe las entradas como \n Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f,Wr,Wl,Wt).

Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f,Wr,Wl,Wt)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        fT=Taylor1(f_step(c_f,h_f,T0),p)
        WrT=Taylor1(Wr,p)
        WlT=Taylor1(Wl,p)
        WtT=Taylor1(Wt,p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i+WrT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i+WlT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i+WtT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
    end
    return (t,R,L,T)
end
# Out:
# Testosterone2_Hormones (generic function with 1 method)

# %%
#Valores iniciales
R0=1.0
L0=2.0
T0=1.5

# Tasa de difusión
b1=1.29
b2=0.97
b3=1.39

#Tasas de secreción y prealimentación
g1=10
g2=0.7
    
#Valores para la función f(T)
c=100
h=12

#Intervalo
t0=0.0
tf=80

#Orden de coeficientes
p=10

#Valores de inyección de Hormonas
Wr=0
Wl=0
Wt=c*b3/(2*h)
#c*b3/h valor crítico

#Wt 1/2 del crítico
t_h2_Wtc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[1];
R_h2_Wtc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[2];
L_h2_Wtc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[3];
T_h2_Wtc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[4];

#Valores de inyección de Hormonas
Wr=0
Wl=0
Wt=c*b3/h

#Wt del crítico
t_h2_Wtc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[1];
R_h2_Wtc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[2];
L_h2_Wtc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[3];
T_h2_Wtc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[4];

c*b3/h
# Out:
# 11.583333333333334

# %%
plot(t_h2_Wtc_1_2,R_h2_Wtc_1_2,"r-",label="R")
plot(t_h2_Wtc_1_2,T_h2_Wtc_1_2, "b-",label="T")
plot(t_h2_Wtc_1_2,L_h2_Wtc_1_2, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE_modelo2_valor_no_critico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002F86BC88>)
# PyObject <matplotlib.legend.Legend object at 0x000000002F810F60>

# %% [markdown]
# Tomando valores menores al del valor crítico, el sistema sigue oscilando, y como es de esperarse, se tiene una mayor amplitud inicial para la L en comparación a los modelos previamente analizados, donde se describe la secreción de testosterona "normal" (saludable). Esta situación puede entenderse como el de alguna persona que presente una deficiencia orgánica en la glándula pituitaria y/o en el hipotálamo, lo que ocasiona una secreción anómala de la hormona luteinizante. Este también podría ser el caso de alguien a quien se le suministra de manera externa dicha hormona.

# %%
plot(t_h2_Wtc,R_h2_Wtc,"r-",label="R")
plot(t_h2_Wtc,T_h2_Wtc, "b-",label="T")
plot(t_h2_Wtc,L_h2_Wtc, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE_modelo2_valor_critico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E412780>)
# PyObject <matplotlib.legend.Legend object at 0x000000002FB414A8>

# %% [markdown]
# Para valores mayores al del valor crítico, se observa un cambio bastante drástico en el comportamiento del sistema. Por un lado, sigue habiendo una concentración mayor de hormona L con respecto a las R y T, pero a partir de cierto tiempo ($\pm10$ horas) el sistema se apaga, deja de autoregularse y se alcanza un estado estacionario para la testosterona, que recordando a lo mencionado en la comparación con la esquizofrenia catatónica oscilante, esto corresponde a una patología, privando de salud al hombre en cuestión.

# %%
#Valores de inyección de Hormonas
Wr=c*b1*b2*b3 / (h*g1*g2) / 2
Wl=0
Wt=0
#c*b1*b2*b3 / (h*g1*g2) valor crítico para Wr

#Wt 1/2 del crítico
t_h2_Wrc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[1];
R_h2_Wrc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[2];
L_h2_Wrc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[3];
T_h2_Wrc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[4];

#Valores de inyección de Hormonas
Wr=c*b1*b2*b3 / (h*g1*g2)
Wl=0
Wt=0

#Wr del crítico
t_h2_Wrc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[1];
R_h2_Wrc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[2];
L_h2_Wrc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[3];
T_h2_Wrc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[4];

c*b1*b2*b3 / (h*g1*g2)
# Out:
# 2.0706035714285713

# %%
#Manteniendo los mismos valores pero eligiendo el primer modelo

#Valores para la función f(T)
A=2
K=1
m=12

#Valores de inyección de Hormonas
Wr=0
Wl=0
Wt=0.5

#Valor crítico
0.5

#Orden de coeficientes
p=10

t_h1_Wtc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[1];
R_h1_Wtc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[2];
L_h1_Wtc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[3];
T_h1_Wtc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[4];

Wt=0.25
t_h1_Wtc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[1];
R_h1_Wtc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[2];
L_h1_Wtc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[3];
T_h1_Wtc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[4];

# %% [markdown]
# Ahora se analiza qué ocurre cuando al cuerpo se le suministra una dosis de la hormona R.

# %%
plot(t_h2_Wrc_1_2,R_h2_Wrc_1_2,"r-",label="R")
plot(t_h2_Wrc_1_2,T_h2_Wrc_1_2, "b-",label="T")
plot(t_h2_Wrc_1_2,L_h2_Wrc_1_2, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo2 valor no critico Wr.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E412518>)
# PyObject <matplotlib.legend.Legend object at 0x000000000116C080>

# %% [markdown]
# Cuando el valor de la dosis es menor que el valor crítico se observa que la concentración de las tres hormonas oscila. El cambio más notable es la amplitud inicial pero esto se debe a las condiciones iniciales. Por tanto, el sistema no siente un gran efecto por la fuente externa.

# %%
plot(t_h2_Wrc,R_h2_Wrc,"r-",label="R")
plot(t_h2_Wrc,T_h2_Wrc, "b-",label="T")
plot(t_h2_Wrc,L_h2_Wrc, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo2 valor crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E42F9E8>)
# PyObject <matplotlib.legend.Legend object at 0x00000000024B3C50>

# %% [markdown]
# En este caso, el valor de la suministración es mayor que el valor crítico. Cuando ocurre esto, el sistema colapsa después de menos de 10 horas, es decir, la concentración de hormonas deja de oscilar. Entonces el sistema llega a un estado estacionario.

# %%
#Valores de inyección de Hormonas
Wr=0
Wl=c*b2*b3 / (h*g2) / 2
Wt=0
#c*b2*b3 / (h*g2) valor crítico para Wl

#Wt 1/2 del crítico
t_h2_Wlc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[1];
R_h2_Wlc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[2];
L_h2_Wlc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[3];
T_h2_Wlc_1_2=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[4];

#Valores de inyección de Hormonas
Wr=0
Wl=c*b2*b3 / (h*g2)
Wt=0

#Wr del crítico
t_h2_Wlc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[1];
R_h2_Wlc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[2];
L_h2_Wlc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[3];
T_h2_Wlc=Testosterone2_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,Wr,Wl,Wt)[4];

c*b2*b3 / (h*g2)
# Out:
# 16.051190476190477

# %% [markdown]
# Se realiza el mismo procedimiento pero esta vez, se suministra la hormona L. En las siguientes dos gráficas se observa que el modelo adopta el mismo comportamiento que en los dos casos anteriores. Esto es, la concentración de las hormonas continúa oscilando cuando el valor es menor que el valor crítico, y por otro lado, el modelo llega a un estado estacionario cuando el valor es mayor que el valor crítico.

# %%
plot(t_h2_Wlc_1_2,R_h2_Wlc_1_2,"r-",label="R")
plot(t_h2_Wlc_1_2,T_h2_Wlc_1_2, "b-",label="T")
plot(t_h2_Wlc_1_2,L_h2_Wlc_1_2, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo2 valor no critico Wr.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000000FD9C50>)
# PyObject <matplotlib.legend.Legend object at 0x00000000026EA5F8>

# %%
plot(t_h2_Wlc,R_h2_Wlc,"r-",label="R")
plot(t_h2_Wlc,T_h2_Wlc, "b-",label="T")
plot(t_h2_Wlc,L_h2_Wlc, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo2 valor crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000026A2A90>)
# PyObject <matplotlib.legend.Legend object at 0x000000002E3A1748>

# %% [markdown]
# ### Fuente Externa modelo 1
#
# Ahora se analizará la misma situación de adición hormonal extra, pero con el modelo donde la función de retroalimentación no corresponde a la del modelo de la esquizofrenia. como para este caso no se tenían valores críticos teóricos se procedió probando numéricamente.

# %%
plot(t_h1_Wtc_1_2,R_h1_Wtc_1_2,"r-",label="R")
plot(t_h1_Wtc_1_2,T_h1_Wtc_1_2, "b-",label="T")
plot(t_h1_Wtc_1_2,L_h1_Wtc_1_2, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE_modelo1_valor_no_critico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002DE88C50>)
# PyObject <matplotlib.legend.Legend object at 0x000000002E2A1780>

# %% [markdown]
# Esta gráfica corresponde a valores menores al valor crítico. Apreciamos nuevamente un comportamiento oscilante  pero la amplitud de la oscilación de la hormona cuya concentración es aumentada externamente es mayor a las otras dos, cosa que difiere al modelo pasado (donde la función de retroalimentación era la Heaviside). Otra cosa importante de notar es que el valor crítico para ambos modelos difiere, pero esto es de esperarse debido a que la función de retroalimentación es distinta.

# %%
plot(t_h1_Wtc,R_h1_Wtc,"r-",label="R")
plot(t_h1_Wtc,T_h1_Wtc, "b-",label="T")
plot(t_h1_Wtc,L_h1_Wtc, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo1 valor crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E2E5F60>)
# PyObject <matplotlib.legend.Legend object at 0x000000002E3A1630>

# %% [markdown]
# Esta gráfica corresponde a valores mayores al valor crítico. A diferencia del modelo pasado aquí la oscilación no se extingue del todo, sólo reduce drásticamente su amplitud con forme avanza el tiempo. Analíticamente se debe a la forma de la función de retroalimentación, la cual no es constante.

# %% [markdown]
# Graficamos el diagrama de concentración de suero.

# %%
plot(L_h1_Wtc,T_h1_Wtc,"b-", label="Wt>Wtc")
plot(L_h1_Wtc_1_2,T_h1_Wtc_1_2,"r-", label="Wt<Wtc")

title("Concentración de suero")
xlabel(L"L[\frac{ng}{ml}]")
ylabel(L"T[\frac{ng}{ml}]")

legend(loc="upper right",fancybox="true")
#savefig("FE_modelo1_concentracion_de_suero.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002DE3AC88>)
# PyObject <matplotlib.legend.Legend object at 0x000000000275F470>

# %%
#Manteniendo los mismos valores iniciales pero eligiendo el primer modelo

#Valores para la función f(T)
A=2
K=1
m=12

#Valores de inyección de Hormonas
Wr=0.068
Wl=0
Wt=0

#Valor crítico
0.068

#Se aumenta el tiempo
tf=80

#Orden de coeficientes
p=10

t_h1_Wrc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[1];
R_h1_Wrc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[2];
L_h1_Wrc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[3];
T_h1_Wrc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[4];

Wr=0.068 /2
t_h1_Wrc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[1];
R_h1_Wrc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[2];
L_h1_Wrc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[3];
T_h1_Wrc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[4];

# %%
plot(t_h1_Wrc_1_2,R_h1_Wrc_1_2,"r-",label="R")
plot(t_h1_Wrc_1_2,T_h1_Wrc_1_2, "b-",label="T")
plot(t_h1_Wrc_1_2,L_h1_Wrc_1_2, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo1 valor no crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000002783F28>)
# PyObject <matplotlib.legend.Legend object at 0x00000000321A6DD8>

# %%
plot(t_h1_Wrc,R_h1_Wrc,"r-",label="R")
plot(t_h1_Wrc,T_h1_Wrc, "b-",label="T")
plot(t_h1_Wrc,L_h1_Wrc, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo1 valor crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E3C7908>)
# PyObject <matplotlib.legend.Legend object at 0x0000000034CF5908>

# %%
plot(L_h1_Wrc,T_h1_Wrc,"b-")
plot(L_h1_Wrc_1_2,T_h1_Wrc_1_2,"r-")

title("Concentración de suero")
xlabel(L"L[\frac{ng}{mol}]")
ylabel(L"T[\frac{ng}{mol}]")

#savefig("FE modelo1 concentración de suero.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003765E358>)
# PyObject <matplotlib.text.Text object at 0x000000002F75ACC0>

# %%
#Manteniendo los mismos valores iniciales pero eligiendo el primer modelo

#Valores para la función f(T)
A=2
K=1
m=12

#Valores de inyección de Hormonas
Wr=0
Wl=0.56
Wt=0

#Valor crítico
0.56

#Se aumenta el tiempo
tf=160

#Orden de coeficientes
p=10

t_h1_Wlc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[1];
R_h1_Wlc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[2];
L_h1_Wlc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[3];
T_h1_Wlc=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[4];

Wl=0.25
t_h1_Wlc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[1];
R_h1_Wlc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[2];
L_h1_Wlc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[3];
T_h1_Wlc_1_2=Testosterone1_Hormones(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,Wr,Wl,Wt)[4];

# %%
plot(t_h1_Wlc_1_2,R_h1_Wlc_1_2,"r-",label="R")
plot(t_h1_Wlc_1_2,T_h1_Wlc_1_2, "b-",label="T")
plot(t_h1_Wlc_1_2,L_h1_Wlc_1_2, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo1 valor no crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000351D92E8>)
# PyObject <matplotlib.legend.Legend object at 0x0000000037682438>

# %%
plot(t_h1_Wlc,R_h1_Wlc,"r-",label="R")
plot(t_h1_Wlc,T_h1_Wlc, "b-",label="T")
plot(t_h1_Wlc,L_h1_Wlc, "g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("FE modelo1 valor crítico.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000034CF5DA0>)
# PyObject <matplotlib.legend.Legend object at 0x00000000321AA208>

# %%
plot(L_h1_Wlc,T_h1_Wlc,"b-")
plot(L_h1_Wlc_1_2,T_h1_Wlc_1_2,"r-")

title("Concentración de suero")
xlabel(L"L[\frac{ng}{mol}]")
ylabel(L"T[\frac{ng}{mol}]")

#savefig("FE modelo1 concentración de suero.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003BCEB6A0>)
# PyObject <matplotlib.text.Text object at 0x000000003BD79048>

# %% [markdown]
# El comportamiento para los valores críticos de inyección de las hormonas L y R son similares a lo analizado con T, sin embargo en los diagramas de concentración de suero no se presenta lo mismo. Para T se observó como el valor crítico colapsó a un punto en la orbita del valor no crítico, mientras que en L y R ambas giran alrededor del mismo punto de estabilidad y la del valor crítico colapsa a este.

# %% [markdown]
# ### Pubertad en el segundo modelo.
#
# La pubertad está causada por uno o una combinación de los siguientes factores:
#
# (i) Un incremento de la sensibilidad pituitaria para LHRH
#
# Esto se representa con un incremento en $g_{1}$.
#
# (ii) Un incremento de la sensibilidad gonadal para LH
#
# Esto se representa con un incremento en $g_{2}$.
#
# (iii) Un incremento de la sensibilidad hipotálamica hacia la retroalimentación negativa de la testosterona
#
# Esto se representa con un incremento en h, dentro de la función f(T).
#
# (iv) Un incremento en la tasa de secreción tónica de LHRH del hipotálamo
#
# Esto se representa con un incremento en c, dentro de la función f(T).

# %%
"""
La función Testosterone2_Pubertad resuelve la misma ecuación que Testosterone2, pero considerando que g1,g2,h y c ya no son
constantes y aumentan en una tasa fija tg1,tg2,th y tc. La función recibe los valores en el siguiente orden: 
\n Testosterone2(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f,tg1,tg2,th,tc)

Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone2_Pubertad(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f,tg1,tg2,th,tc)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    ti=t0
    n=1
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        fT=Taylor1(f_step(c_f,h_f,T0),p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
        if t0-ti > n
            g1 += tg1
            g2 += tg2
            h_f += th
            c_f += tc
            n += 1
        end
    end
    return (t,R,L,T)
end
# Out:
# Testosterone2_Pubertad (generic function with 1 method)

# %%
#Valores iniciales
R0=3.0
L0=5.0
T0=10.0

# Tasa de difusión
b1=1.29
b2=0.97
b3=1.39

#Tasas de secreción y prealimentación
g1=10
g2=0.7
    
#Valores para la función f(T)
c=100
h=12

#Tasas de crecimiento por pubertad
tg1 = 0.1
tg2 = 0.01
th = 0.1
tc = 1

#Intervalo
t0=0.0
tf=80.0

#Orden de coeficientes
p=10

#valores
t_p2=Testosterone2_Pubertad(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg1,tg2,th,tc)[1];
R_p2=Testosterone2_Pubertad(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg1,tg2,th,tc)[2];
L_p2=Testosterone2_Pubertad(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg1,tg2,th,tc)[3];
T_p2=Testosterone2_Pubertad(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg1,tg2,th,tc)[4];

# %%
plot(t_p2,R_p2,"r-",label="R")
plot(t_p2,T_p2,"b-",label="T")
plot(t_p2,L_p2,"g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("pubertad.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003540ACF8>)
# PyObject <matplotlib.legend.Legend object at 0x0000000035388710>

# %% [markdown]
# Como es de esperarse, la amplitud de las oscilaciones correspondientes a la secreción de T y de L aumenta conforme avanza el tiempo, aunque es importante remarcar que para poder describir un sistema biológicamente aceptable, éstas no deben diverger. Por lo que se debe establercer un límite al que llegan los parámetros modificados.

# %%
plot(L_p2,T_p2)

title("Concentración de Suero")
xlabel(L"L[\frac{ng}{ml}]")
ylabel(L"T[\frac{ng}{ml}]")

#savefig("pubertad concentración de suero.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003BDC5EF0>)
# PyObject <matplotlib.text.Text object at 0x000000003CDB8208>

# %% [markdown]
# Este diagrama de concentración sigue exhibiendo el comportamiento de órbitas cerradas, pero a diferencia de las pasadas éstas dejan de ser periódicas, que es de esperarse debido al aumento de concentración de T y de L.

# %% [markdown]
# ### Castración

# %% [markdown]
# La castración dentro del modelo se representa haciendo que $g_{2}$ disminuya, i.e. el efecto de producción de testosterona por las gónadas se ve reducido. Para el primer modelo el valor de m realmente no afecta como cambia la solución. Sólo si en cada intervalo es periódico o estable. En el segundo modelo dependiendo de que tan rápido disminuye $g_{2}$ la hormona L diverge.

# %%
"""
La función Testosterone2_Castration resuelve la misma ecuación que Testosterone2, pero considerando que g2 decrece
deacuerdo a una tasa fija tg2. La función recibe los valores en el siguiente orden: 
\n Testosterone2(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)

Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    ti=t0
    n=10
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            fT=A/(K+TT^m)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
        if t0-ti > n && g2 >0
            g2 += tg2
            n += 10
        else
            g2 = g2
        end
    end
    return (t,R,L,T)
end
# Out:
# Testosterone1_Castration (generic function with 1 method)

# %%
"""
La función Testosterone2_Castration resuelve la misma ecuación que Testosterone2, pero considerando que g2 decrece
deacuerdo a una tasa fija tg2. La función recibe los valores en el siguiente orden: 
\n Testosterone2(p,R0,T0,L0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f,tg2)

Regresa 4 arreglos en el siguiente orden: t,R,L,T correspondientes al valor de las funciones en ese tiempo.
"""

function Testosterone2_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c_f,h_f,tg2)    
    #Valores iniciales
    t=[t0]
    R=[R0]
    L=[L0]
    T=[T0]
    ti=t0
    n=10
    
    #solución a la ecuación diferencial
    while t0 < tf
        RT=Taylor1(R0,p)
        LT=Taylor1(L0,p)
        TT=Taylor1(T0,p)
        fT=Taylor1(f_step(c_f,h_f,T0),p)
        #Se evaluan los coeficientes de Taylor utilizando las reglas de correspondencia
        for i in range(1,p)
            RT.coeffs[i+1] = fT.coeffs[i]-b1*RT.coeffs[i]/i
            LT.coeffs[i+1] = g1*RT.coeffs[i]/i-b2*LT.coeffs[i]/i
            TT.coeffs[i+1] = g2*LT.coeffs[i]/i-b3*TT.coeffs[i]/i
        end
        #Se obtienen los pasos de integración para cada función
        hR=h_find(RT.coeffs,p)
        hL=h_find(LT.coeffs,p)
        hT=h_find(TT.coeffs,p)
        #Se elige el mínimo entre ellos para que todos los arreglos tengan la misma longiud
        h=minimum([hR,hL,hT])
        t0=t0+h
        #Se evalúa la función en el siguiente punto utilizando la fórmula de Horner.
        R0=evaluate(RT,h)
        L0=evaluate(LT,h)
        T0=evaluate(TT,h)
        push!(t,t0)
        push!(R,R0)
        push!(L,L0)
        push!(T,T0)
        if t0-ti > n && g2 >0
            g2 += tg2
            n += 10
        else
            g2 = g2
        end
    end
    return (t,R,L,T)
end
# Out:
# Testosterone2_Castration (generic function with 1 method)

# %%
#Se analiza el caso de la castración en el macho, esto se representa haciendo una tasa de tg2=-0.1 cada 10 horas. Representa 
#castración química, hasta que ya no hay secreción por parte de las gónadas

#Valores iniciales
R0=1.0
L0=1.0
T0=1.0

# Tasa de difusión
b1=1.29
b2=0.97
b3=1.39

#Tasas de secreción y prealimentación
g1=10
g2=0.7

#Tasas de reducción por castración
tg2 = -0.1
    
#Valores para la función f(T)
A=2
K=1
m=12

#Intervalo
t0=0.0
tf=80

#Orden de coeficientes
p=10

t_castration1_12=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[1];
R_castration1_12=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[2];
L_castration1_12=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[3];
T_castration1_12=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[4];

# %%
#Valores para la función f(T)
A=2
K=1
m=7

t_castration1_8=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[1];
R_castration1_8=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[2];
L_castration1_8=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[3];
T_castration1_8=Testosterone1_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,A,K,m,tg2)[4];

# %%
#Valores para la función f(T) segundo modelo
c=100
h=12
# Out:
# 12

# %%
t_castration2=Testosterone2_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg2)[1];
R_castration2=Testosterone2_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg2)[2];
L_castration2=Testosterone2_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg2)[3];
T_castration2=Testosterone2_Castration(p,R0,L0,T0,t0,tf,g1,g2,b1,b2,b3,c,h,tg2)[4];

# %%
plot(t_castration1_12,R_castration1_12,"r-",label="R")
plot(t_castration1_12,T_castration1_12,"b-",label="T")
plot(t_castration1_12,L_castration1_12,"g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")

#savefig("castración hormonas primer modelo m=12.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003C4A5E48>)
# PyObject <matplotlib.legend.Legend object at 0x000000003CA17F60>

# %% [markdown]
# Primeramente notamos que las oscilaciones de L se disparan  a partir de cierto punto y esto se debe justo a que el parámetro asociado a esta hormona es la $g_2$, que para la castración tiende a 0, por lo que se dispara. En cuanto a las dos hormonas apreciamos que, como es de esperarse, a partir de la eliminación de $g_{2}$, se corta la producción de testosterona y esta rápidamente se va a cero. Adicionalmente debido a que se eligió reducir el valor de $g_{2}$ en pasos de 10 horas, la solución se comporta similar en cada uno de estos intervalos.

# %%
plot(t_castration1_8,R_castration1_8,"r-",label="R")
plot(t_castration1_8,T_castration1_8,"b-",label="T")
plot(t_castration1_8,L_castration1_8,"g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")

legend(loc="upper right",fancybox="true")
#savefig("castración hormonas primer modelo m=8.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003C9D6A90>)
# PyObject <matplotlib.legend.Legend object at 0x00000000405B9240>

# %% [markdown]
# Aquí seguimos apreciando un comportamiento similar al antes mencionado. Sólo que al haber elegido una $m$ menor ya casi no se presenta oscialación en cada intervalo.

# %%
plot(t_castration2,R_castration2,"r-",label="R")
plot(t_castration2,T_castration2,"b-",label="T")
plot(t_castration2,L_castration2,"g-",label="L")

title("Concentración de hormonas en la sangre")
xlabel("Tiempo [H]")
ylabel("ng/ml")
#xlim(0,10)
ylim(-10,120)

legend(loc="upper right",fancybox="true")
#savefig("castración hormonas segundo modelo.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003CAB72B0>)
# PyObject <matplotlib.legend.Legend object at 0x0000000037BA1F28>

# %% [markdown]
# Para el segundo modelo tenemos el mismo comportamiento previamente discutido, con la excepción del valor inicial de L y el valor final de R.

# %%
plot3D(t_castration1_8,L_castration1_8,T_castration1_8)

title("Concentración de Suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")
#savefig("castración suero primer modelo m=8.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003CA8E400>)
# PyObject <matplotlib.text.Text object at 0x000000003BE04B38>

# %% [markdown]
# Esto corresponde a que como la solución ya no es oscilante, las curvas ya no son órbitas periódicas cerradas. Esto se sigue para la siguiente gráfica, donde sólo se ha aumentado el valor de m.

# %%
plot3D(t_castration1_12,L_castration1_12,T_castration1_12)

title("Concentración de Suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")
#savefig("castración suero primer modelo m=12.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000321A4518>)
# PyObject <matplotlib.text.Text object at 0x000000004047A4E0>

# %%
plot3D(t_castration2,L_castration2,T_castration2)


title("Concentración de Suero")
xlabel(L"Tiempo [H]")
ylabel(L"L[\frac{ng}{ml}]")
zlabel(L"T[\frac{ng}{ml}]")
#savefig("castración suero segundo modelo.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000040492358>)
# PyObject <matplotlib.text.Text object at 0x000000003CA1DD68>

# %% [markdown]
# Por lo tanto podemos observar que a pesar de que este modelo sí explica las fluctuaciones cíclicas en los niveles de las 3 hormonas involucradas, contradice lo esperado experimentalmente que es que los niveles de L y de R continuen oscilando después de la castración, mientras que en el modelo teórico éstos alcanzan un comportamiento constante. Según el trabajo de David Greenhalgh y Qamar Khan, esta contradicción se resuelve tomando en cuenta el retardo temporal que existe entre la secreción de L y su respuesta en las gónadas con la secreción de T.
#
# Por otro lado, no se observa que haya dependencia de la 'm' en la función de retroalimentación. Además, el parametro que más altera el valor es la b3, la tasa de difusión de la testosterona en la sangre. No obstante sigue comportándose como el primer modelo.

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Se verificó que el estado estacionario del sistema es independiente de las condiciones inciales, aunque si depende de la función de retroalimentación.
#
# Se lograron encontrar valores para los cuales las soluciones en el diagrama de sueros exhiben el comportamiento de ciclo límite. Por otra parte, el orden de estos valores críticos para el segundo modelo en el caso de una fuente externa de hormonas, son de 16, 11 y 2 para L, T y R respectivamente. Esto va de acuerdo a la concentración de cada hormona que se observa en las gráficas correspondientes. Por otro lado, se corroboraron numéricamente los resultados propuestos por Smith.
#
# Se modeló la castración y la pubertad a tiempos pequeños a partir de considerar variables los parametros de la ecuación diferencial.
#
# Para poder describir adecuadamente la concentración de testosterona se debe incluir un retardo dentro de la ecuación diferencial. Esto se debe a que incluso en la castración, el hecho de que la testosterona se vaya a cero las otras dos hormonas deben seguir oscilando en lugar de permanecer constantes. Ademas, la regulación de la testosterona no es inmediata. Se debe tomar en cuenta el tiempo que tardan las hormonas en trasladarse por el torrente sanguíneo.

# %% [markdown]
# #### Referencias:
#
# [1] Murray, J. D. 1989. Mathematical Biology. Volume 19.
#
# [2] Smith, William R. "Hypothalamic regulation of pituitary secretion of luteinizing hormone—II feedback control of gonadotropin secretion." Bulletin of Mathematical Biology 42.1 (1980): 57-78.
#
# [3] Cronin, Jane. "The Danziger-Elmergreen theory of periodic catatonic schizophrenia." Bulletin of mathematical biology 35.5-6 (1973): 689-707.
