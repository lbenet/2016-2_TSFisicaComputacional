# %% [markdown]
# # Aqui se visualizan facilmente archivos de `/test`

# %%
using ChaosCrypto
using PyPlot
using Interact
using WAV
# Out:
# <script charset="utf-8">(function ($, undefined) {
#
#     function createElem(tag, attr, content) {
# 	// TODO: remove jQuery dependency
# 	var el = $("<" + tag + "/>").attr(attr);
# 	if (content) {
# 	    el.append(content);
# 	}
# 	return el[0];
#     }
#
#     // A widget must expose an id field which identifies it to the backend,
#     // an elem attribute which is will be added to the DOM, and
#     // a getState() method which returns the value to be sent to the backend
#     // a sendUpdate() method which sends its current value to the backend
#     var Widget = {
# 	id: undefined,
# 	elem: undefined,
# 	label: undefined,
# 	getState: function () {
# 	    return this.elem.value;
# 	},
# 	sendUpdate: undefined
#     };
#
#     var Slider = function (typ, id, init) {
# 	var attr = { type:  "range",
# 		     value: init.value,
# 		     min:   init.min,
# 		     max:   init.max,
# 		     step:  init.step },
# 	    elem = createElem("input", attr),
# 	    self = this;
#
# ...

# %% [markdown]
# #### `testejercicio11taylor.jl`

# %%
include("testejercicio11taylor.jl")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97b768160>)
# PyObject <matplotlib.legend.Legend object at 0x7ff97af701d0>

# %% [markdown]
# #### `testejercicio12taylor.jl`

# %%
include("testejercicio12taylor.jl")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97af79f98>)

# %% [markdown]
# #### `testejercicio3.jl`

# %%
include("testejercicio3.jl")
# Out:
# Interact.Slider{Float64}(Signal{Float64}(0.041, nactions=0),"φ",0.041,0.001:0.01:0.091,true)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97b8d9ac8>)

# %% [markdown]
# #### `ejercicio3taylor`

# %%
include("ejercicio3taylor.jl")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97df28668>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97b8e6128>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97b88fef0>)

# %% [markdown]
# #### `testaudio.jl`

# %%
include("testaudio.jl")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff97ae59c88>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7ff97b30a240>

# %%
typeof(s)
# Out:
# Array{Any,1}

# %%
sfloat = convert(Array{Float64,1}, s)
# Out:
# 10002-element Array{Float64,1}:
#  1.0
#  1.001
#  1.00258
#  1.00473
#  1.00745
#  1.01074
#  1.01458
#  1.01897
#  1.02391
#  1.0294
#  1.03542
#  1.04198
#  1.04907
#  ⋮
#  9.24932
#  9.14962
#  9.05059
#  8.95224
#  8.85458
#  8.75763
#  8.6614
#  8.56589
#  8.47112
#  8.3771
#  8.28384
#  8.19135

# %%
typeof(sfloat)
# Out:
# Array{Float64,1}

# %%
mhatfloat = convert(Array{Float64,1}, mhat)
mfloat = convert(Array{Float64,1}, m)
# Out:
# 10002-element Array{Float64,1}:
#   0.0
#   0.001
#   0.002
#   0.003
#   0.00399999
#   0.00499998
#   0.00599996
#   0.00699994
#   0.00799991
#   0.00899988
#   0.00999983
#   0.0109998
#   0.0119997
#   ⋮
#  -0.535603
#  -0.536448
#  -0.537291
#  -0.538134
#  -0.538977
#  -0.539819
#  -0.54066
#  -0.541501
#  -0.542342
#  -0.543182
#  -0.544021
#  -0.54486

# %%
wavwrite(sfloat, "asdf.wav", )
# Out:
# LoadError: MethodError: `wavwrite` has no method matching wavwrite(::Array{Float64,1}, ::ASCIIString, ::Int64, ::Int64, ::Int64)
# Closest candidates are:
#   wavwrite{T<:AbstractFloat}(::AbstractArray{T<:AbstractFloat,N}, ::AbstractString)
#   wavwrite(::AbstractArray{T,N}, ::AbstractString)
#   wavwrite(::AbstractArray{T,N}, !Matched::Real, ::Real, !Matched::AbstractString)
#   ...
# while loading In[52], in expression starting on line 1

# %%
typeof(1600)
# Out:
# Int64

# %%
convertfreq = convert(Real, 16000)
# Out:
# 16000

# %%
typeof(convertfreq)
# Out:
# Int64

# %%
wavwrite(mfloat, "mmmmm.wav", Fs=16000)

# %%
?wavwrite
# Out:
# search: wavwrite
# No documentation found.
#
# `WAV.wavwrite` is a generic `Function`.
#
# ```julia
# # 11 methods for generic function "wavwrite":
# wavwrite(x::WAV.WAVArray{T,N}, io::IO) at /home/ignacio/.julia/v0.4/WAV/src/AudioDisplay.jl:9
# wavwrite(y::AbstractArray{Int32,N}, io::IO) at /home/ignacio/.julia/v0.4/WAV/src/WAV.jl:760
# wavwrite{T<:Integer}(y::AbstractArray{T<:Integer,N}, io::IO) at /home/ignacio/.julia/v0.4/WAV/src/WAV.jl:758
# wavwrite{T<:AbstractFloat}(y::AbstractArray{T<:AbstractFloat,N}, io::IO) at /home/ignacio/.julia/v0.4/WAV/src/WAV.jl:762
# wavwrite(samples::AbstractArray{T,N}, io::IO) at /home/ignacio/.julia/v0.4/WAV/src/WAV.jl:652
# wavwrite(y::AbstractArray{Int32,N}, filename::AbstractString) at /home/ignacio/.julia/v0.4/WAV/src/WAV.jl:761
# wavwrite{T<:Integer}(y::AbstractArray{T<:Integer,N}, filename::AbstractString) at /home/ignacio/.julia/v0.4/WAV/src/WAV.jl:759
# ...

# %%
wavwrite(mhatfloat, "mhat.wav", Fs=16000)
