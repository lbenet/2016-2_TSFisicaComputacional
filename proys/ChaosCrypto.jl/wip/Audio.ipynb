# %%
using WAV
using DSP
using PyPlot

# %%
# Loading and plotting an audio signal
s, fs = wavread("test.wav")

plot(0:1/fs:(length(s)-1)/fs, s)
xlabel("Time [s]")
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3aa6d3a1d0>)

# %%
include("AudioDisplay.jl")

using AudioDisplay

audioplayer("test.wav")
# Out:
# <audio controls="controls" {autoplay}>
# <source src="test.wav" />
# Your browser does not support the audio element.
# </audio>

# %%
typeof(s)
# Out:
# Array{Float64,2}

# %%
typeof(fs)
# Out:
# Float32

# %%
fs
# Out:
# 16000.0f0

# %%
s
# Out:
# 10891x1 Array{Float64,2}:
#  -0.0367138
#  -0.0629902
#  -0.0516984
#  -0.05356
#  -0.0451369
#  -0.0443739
#  -0.0388501
#  -0.0368969
#  -0.0314646
#  -0.0302438
#  -0.030427
#  -0.0343028
#  -0.0323191
#   ⋮
#   0.000396741
#   9.15555e-5
#  -0.000152593
#  -3.05185e-5
#   0.000335704
#   0.000335704
#   0.000518815
#   0.000824
#   0.000549333
#   0.000946074
#   0.0013123
#   0.0013123
